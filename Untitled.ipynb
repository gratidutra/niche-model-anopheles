# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.spatial import ConvexHull
import folium

# %%
from unicodedata import decimal


df = pd.read_csv("data/processed/kmeans.csv")

df = df.rename(columns = {'Unnamed: 0': 'id'})

# %%
df[df.decimalLongitude < -100]
# Out:
#         id  decimalLatitude  decimalLongitude  rich
# 3522  3523        16.961667       -100.138611     1
# 3529  3530        17.007222       -100.087500     1
# 3567  3568        17.152333       -100.410750     1
# 3568  3569        17.152500       -100.410278     1
# 3581  3582        17.205806       -100.628555     1
# ...    ...              ...               ...   ...
# 4697  4698        31.901000       -110.833000     1
# 4719  4720        35.249440       -112.190300     1
# 4724  4725        36.910231       -121.756895     1
# 4725  4726        37.430235       -122.170812     1
# 4726  4727        37.977220       -100.862800     1
#
# [526 rows x 4 columns]

# %%
K_clusters = range(1,10)

kmeans = [KMeans(n_clusters=i) for i in K_clusters]

Y_axis = df[['decimalLatitude']]

X_axis = df[['decimalLongitude']]

score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]

# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
from enum import unique


kmeans = KMeans(n_clusters = 3, init ='k-means++')
kmeans.fit(df[df.columns[1:3]]) # Compute k-means clustering.
df['cluster_label'] = kmeans.fit_predict(df[df.columns[1:3]])+1
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(df[df.columns[1:3]]) # Labels of each point
df.head(10)
# Out:
#    id  decimalLatitude  decimalLongitude  rich  cluster_label
# 0   1       -48.816600        -25.500000     1              3
# 1   2       -38.944172        -66.812500     1              3
# 2   3       -38.670214        -66.460937     1              3
# 3   4       -34.599700        -58.381900     1              3
# 4   5       -34.216210        -58.900610     1              3
# 5   6       -33.833300        -59.500000     1              3
# 6   7       -33.800000        -59.500000     1              3
# 7   8       -33.799530        -59.500630     1              3
# 8   9       -33.779999        -59.509998     1              3
# 9  10       -33.778000        -59.514000     1              3

# %%
df.plot.scatter(x = 'decimalLongitude', y = 'decimalLatitude', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 1], centers[:, 0], c='black', s=200, alpha=0.5)

# %%
import numpy as np
df['colors'] = np.where(
    df['cluster_label'] == 1, 'blue', np.where(
    df['cluster_label'] == 2 , 'red', 'green'))

# %%
m = folium.Map(zoom_start=4)
for index, row in df.iterrows():
    folium.CircleMarker([row['decimalLatitude'], row['decimalLongitude']],
                    radius=3, color=row['colors']).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
